# %% [markdown]
# # Exercise:
#
# In this exercise, you will work with a data set in "mtcars.csv" that contains information on 31 cars. We will create a collection of scatterplots showing the relationship between horsepower (hp) and miles per gallon (mpg), displacement(disp) and quarter mile time (qsec).  Also, in each of these plots we will distinguish between automatic (am = 0) and manual (am=1) cars. Please follow the following steps:
#
# **Step 0:** create a gitHub repository for this exercise. In your local repository, copy this jupyter file. Make sure you commit and push changes to your online repository after each step.
#
# **Step 1:** Read the file into a data frame
#
# **Step 2:** Dispaly statistics about differnt columns
#
# **Step 3:** Create two dataframes from the origial one to represent manual and automatic cars
#
# **Step 4:** Now Let's first create a 1x3 figure on which we will place the three plots. Give the figure a title of "Understanding the Effect of Horspower on other Features"
#
# **Step 5:** On the first axis plot hp versus miles per gallon for manual cars only
#
# **Step 6:** Add to the same axis a plot for automatic car, using a different color
#
# **Step 7:** Repeat 5 and 6 for hp vs qsec
#
# **Step 8:** Repeat 5 and 6 for hp vs disp
#
# **Step 9:** Use descriptive labels, good markers, colors, and legends to enhance your graph
#
# **Step 10:** Save figures to your computer
#
#
# Advanced: Add two horizontal lines to the first plot denoting the respective average mpg for automatic and manual cars respectively.

# %% [markdown]
# ### Step 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
mtcars = pd.read_csv("mtcars.csv")

# %% [markdown]
# ### Step 2

# %%
mtcars.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
mtcars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
import seaborn as sns
sns.heatmap(mtcars.corr(), annot=True)
plt.title("Pearson Correlation Matrix")
# Out:
# C:\Users\wwden\AppData\Local\Temp\ipykernel_25892\97237069.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(mtcars.corr(), annot=True)
# Text(0.5, 1.0, 'Pearson Correlation Matrix')

# %%
mtcars.hist(figsize = (16,20))
plt.plot()
# Out:
# []

# %% [markdown]
# ### Step 3

# %%
manualCars = mtcars[mtcars["am"] == 0]
automaticCars = mtcars[mtcars["am"] == 1]

# %% [markdown]
# ### Step 4 - 10

# %%
# Step 4
figure, axis = plt.subplots(1,3, figsize = (15,5))
figure.suptitle("Understanding the Effect of Horspower on other Features")

# Step 5
axis[0].plot(manualCars["hp"],manualCars["mpg"],'ro', label = 'manual')
axis[0].title.set_text("hp vs mpg for automatic and manual cars")
axis[0].set_xlabel("mpg")
axis[0].set_ylabel("hp")

# Step 6
axis[0].plot(automaticCars["hp"],automaticCars["mpg"],'bo', label = 'automatic')
axis[0].legend()

# Step 7
axis[1].plot(manualCars["hp"],manualCars["qsec"],'ro', label = 'manual')
axis[1].title.set_text("hp vs qsec for automatic and manual cars")
axis[1].set_xlabel("qsec")
axis[1].set_ylabel("hp")

axis[1].plot(automaticCars["hp"],automaticCars["qsec"],'bo', label = 'automatic')
axis[1].legend()

# Step 8
axis[2].plot(manualCars["hp"],manualCars["disp"],'ro', label = 'manual')
axis[2].title.set_text("hp vs disp for automatic and manual cars")
axis[2].set_xlabel("disp")
axis[2].set_ylabel("hp")

axis[2].plot(automaticCars["hp"],automaticCars["disp"],'bo', label = 'automatic')
axis[2].legend()

# Step 9 all included above

# Step 10
figure.savefig("Horsepower Analysis.png")
